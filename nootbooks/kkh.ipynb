# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# !pip install koreanize-matplotlib
import koreanize_matplotlib

# %%
customers = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_customers_dataset.csv')
geolocation = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_geolocation_dataset.csv')
order_items = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_order_items_dataset.csv')
order_payments = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_order_payments_dataset.csv')
order_reviews= pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_order_reviews_dataset.csv')
orders_dataset = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_orders_dataset.csv')
products_dataset = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_products_dataset.csv')
sellers = pd.read_csv('/content/drive/MyDrive/(새싹) 프로젝트 1/Data/olist_sellers_dataset.csv')

# %%
# 상품 플랫폼 내 상품 카테고리수
products_dataset['product_category_name'].shape
products_dataset['product_category_name'].value_counts()
# Out:
# (32951,)
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
# 주문 id - 리뷰평점 연결 (상품or배송이슈 확인)
order_items
order_items.columns
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# 리뷰데이터 평점 2점대 찾기
# 2점대 3151개
order_reviews.shape
order_reviews.head()
order_reviews['review_score'].value_counts()
score_2_data = order_reviews[order_reviews['review_score'] == 2][['review_id', 'order_id']]
score_2_data
score_2_order_ids = order_reviews[order_reviews['review_score'] == 2]['order_id'].unique()
# Out:
# (99224, 7)
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
# 리뷰 별점 2점대의 order id로 order items 내 id 매칭(상품, 셀러 파악가능)
# 2점 리뷰 주문 ID 개수: 3148
# order_items에서 찾은 2점 리뷰 주문: 3086
# 2점 리뷰 주문 매칭률: 98.03%
order_items.columns
order_items.head()
order_items_ids=order_items['order_id']
score_2_order_ids = order_reviews[order_reviews['review_score'] == 2]['order_id'].unique()
score_2_in_items = set(score_2_order_ids).intersection(order_items_ids)

print(f"2점 리뷰 주문 ID 개수: {len(score_2_order_ids)}")
print(f"order_items에서 찾은 2점 리뷰 주문: {len(score_2_in_items)}")
print(f"2점 리뷰 주문 매칭률: {(len(score_2_in_items)/len(score_2_order_ids))*100:.2f}%")
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# ...

# %%
# 2점 리뷰 판매자, 상품 매칭률 낮음
# 2점 리뷰 매칭된 상품 레코드: 3874
# 관련 고유 판매자 수: 929 / 0.24%
# 관련 고유 상품 수: 2622 / 0.68%
# 전처리 필요 ?  merge의 문제?

score_2_reviews = order_reviews[order_reviews['review_score'] == 2]
score_2_with_items = score_2_reviews.merge(order_items, on='order_id', how='inner')

# 판매자 및 상품 정보 확인
print("=== 2점 리뷰 상품 정보 ===")
print(f"2점 리뷰 매칭된 상품 레코드: {len(score_2_with_items)}")
print(f"관련 고유 판매자 수: {score_2_with_items['seller_id'].nunique()}")
print(f"관련 고유 상품 수: {score_2_with_items['product_id'].nunique()}")

# 기본 정보 확인
print(score_2_with_items[['order_id', 'seller_id', 'product_id', 'review_score']].head(10))
# Out:
# === 2점 리뷰 상품 정보 ===
# 2점 리뷰 매칭된 상품 레코드: 3874
# 관련 고유 판매자 수: 929
# 관련 고유 상품 수: 2622
#                            order_id                         seller_id  \
# 0  0dacf04c5ad59fd5a0cc1faa07c34e39  7ddcbb64b5bc1ef36ca8c151f6ec77df
# 1  aad1dcbe4c9fe2e3486e5e04c6649097  6560211a19b47992c3666cc44a7e94c0
# 2  b1cc044d321053348a5e482ca7e6b2e3  7c67e1448b00f6e969d365cea6b010ab
# 3  bbd1b9ebbc5a09d51caaa2d10e0f93b5  53e4c6e0f4312d4d2107a8c9cddf45cd
# 4  f81ed3e1a19bd4246ee3e90b01359eb0  4c2b230173bb36f9b240f2b8ac11786e
# 5  1e9ea7d5f669d780b187f487a03c3f7b  7ddcbb64b5bc1ef36ca8c151f6ec77df
# 6  33fb6b947580ee29bd0c6babed6049c1  66922902710d126a0e7d26b0e3805106
# 7  468c2f34312a6d270a20c7aef082041c  f8db351d8c4c4c22c6835c19a46f01b0
# 8  a848ecb46fe108b35dd5bd7bf4fdddca  cfb1a033743668a192316f3c6d1d2671
# 9  68993f27a34bd02e3b2c2ebb5c41b9ec  87142160b41353c4e5fca2360caf6f92
#
#                          product_id  review_score
# 0  4413a608a42bd21bbf9d5abbd58c249a             2
# ...

# %%
# 2점대 상품, 카테고리 확인
# === 2점 리뷰 상품 카테고리별 개수 (전체) ===
# product_category_name
# cama_mesa_banho                498 / 침구, 식탁, 욕실용품
# moveis_decoracao               361 / 가구 및 장식
# informatica_acessorios         287 / 컴퓨터 및 악세서리 (카테고리 상단메뉴 x)
# utilidades_domesticas          249 / 생활용품
# beleza_saude                   240 / 미용건강
# 총 카테고리 수: 63
# 총 2점 리뷰 건수: 3811

category_counts = score_2_with_product_info['product_category_name'].value_counts()

print("=== 2점 리뷰 상품 카테고리별 개수 (전체) ===")
print(category_counts)
print(f"\n총 카테고리 수: {len(category_counts)}")
print(f"총 2점 리뷰 건수: {category_counts.sum()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-15-2582628845.py in <cell line: 0>()
#      10 # 총 2점 리뷰 건수: 3811
#      11
# ---> 12 category_counts = score_2_with_product_info['product_category_name'].value_counts()
#      13
#      14 print("=== 2점 리뷰 상품 카테고리별 개수 (전체) ===")
#
# NameError: name 'score_2_with_product_info' is not defined

# %%
# 2점대 판매자 확인
# 3095명

sellers.head()
sellers.shape
sellers['seller_id']
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# (3095, 4)
# 0       3442f8959a84dea7ee197c632cb2df15
# 1       d1b65fc7debc3361ea86b5f14c68d2e2
# 2       ce3ad9de960102d0677a81f5d0bb7b2d
# 3       c0f3eea2e14555b6faeea3dd58c1b1c3
# 4       51a04a8a6bdcb23deccc82b0b80742cf
#                       ...
# 3090    98dddbc4601dd4443ca174359b237166
# 3091    f8201cab383e484733266d1906e2fdfa
# 3092    74871d19219c7d518d0090283e03c137
# ...

# %%
order_reviews.shape # 99224
order_items['order_id'].value_counts() # 98666
# Out:
# (99224, 7)
# order_id
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 5a082b558a3798d3e36d93bfa8ca1eae     1
# 5a07264682e0b8fbb3f166edbbffc6e8     1
# 5a071192a28951b76774e5a760c8c9b7     1
# 5a06fc966a12b41bf401b344464fd4b1     1
# 5a0e5ad33542c79b10be87a344ee0086     1
# Name: count, Length: 98666, dtype: int64

# %%
score_2_with_seller_info = score_2_with_product_info.merge(
    sellers,
    on='seller_id',
    how='left'
)

print("=== 판매자 정보 조인 결과 ===")
print(f"조인 전 레코드 수: {len(score_2_with_product_info)}")
print(f"조인 후 레코드 수: {len(score_2_with_seller_info)}")

# 판매자 정보 매칭 확인
seller_info_matched = score_2_with_seller_info['seller_city'].notna().sum()
print(f"판매자 정보가 매칭된 레코드: {seller_info_matched}")
print(f"판매자 정보 매칭률: {(seller_info_matched / len(score_2_with_seller_info)) * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-20-3777196029.py in <cell line: 0>()
# ----> 1 score_2_with_seller_info = score_2_with_product_info.merge(
#       2     sellers,
#       3     on='seller_id',
#       4     how='left'
#       5 )
#
# NameError: name 'score_2_with_product_info' is not defined

# %%
# 2점 리뷰 데이터와 sellers 데이터 조인
score_2_with_seller_info = score_2_with_product_info.merge(
    sellers,
    on='seller_id',
    how='left'
)

print("=== 판매자 정보 조인 결과 ===")
print(f"조인 전 레코드 수: {len(score_2_with_product_info)}")
print(f"조인 후 레코드 수: {len(score_2_with_seller_info)}")

# 판매자 정보 매칭 확인
seller_info_matched = score_2_with_seller_info['seller_city'].notna().sum()
print(f"판매자 정보가 매칭된 레코드: {seller_info_matched}")
print(f"판매자 정보 매칭률: {(seller_info_matched / len(score_2_with_seller_info)) * 100:.2f}%")

# %%
print("\n=== 상품 카테고리별 2점 리뷰 분포 ===")
if 'product_category_name' in score_2_with_seller_info.columns:
    category_review_counts = score_2_with_seller_info.groupby('product_category_name').size().reset_index(name='review_count')
    category_review_counts = category_review_counts.sort_values('review_count', ascending=False)
    print("카테고리별 2점 리뷰 수 (상위 10개):")
    print(category_review_counts.head(10))

# %%
# 판매자별 2점 리뷰 분포
print("\n=== 판매자별 2점 리뷰 분포 ===")
seller_review_counts = score_2_with_seller_info.groupby('seller_id').size().reset_index(name='review_count')
print(f"2점 리뷰가 있는 판매자 수: {len(seller_review_counts)}")
print(f"평균 2점 리뷰 수: {seller_review_counts['review_count'].mean():.2f}")
print(f"최대 2점 리뷰 수: {seller_review_counts['review_count'].max()}")

# %% [markdown]
# # 타겟설정 :
# - 1회구매자 (97%) 중 높은 상품만족도(리뷰 4,5점) 구매자 대상
# - 1회 구매자의 구매 상품카테고리가 소모성 /반복성 있는경우

# %%
# 잠재구매자 1차 도출 (재구매자 제외) 97% 93099명
customer_counts = customers['customer_unique_id'].value_counts()
repeat_customers = customer_counts[customer_counts == 1]
repeat_customers.shape
repeat_customers.head()

# %%
# 잠재구매자 2차 도출 (기준1-리뷰 4,5점이상) 76470명
customer_counts = customers['customer_unique_id'].value_counts()
single_occurrence_customers = customer_counts[customer_counts == 1].index
single_occurrence_df = customers[customers['customer_unique_id'].isin(single_occurrence_customers)][['customer_unique_id', 'customer_id']]
display(single_occurrence_df)


high_score_orders = order_reviews[order_reviews['review_score'].isin([4, 5])]['order_id']
display(high_score_orders)


high_score_orders_df = pd.DataFrame(high_score_orders, columns=['order_id'])
high_score_customers = pd.merge(high_score_orders_df, orders_dataset[['order_id', 'customer_id']], on='order_id', how='left')
display(high_score_customers)


single_occurrence_df
high_score_and_single_occurrence_customers = pd.merge(high_score_customers, single_occurrence_df, on='customer_id', how='inner')


display(high_score_and_single_occurrence_customers)

# %%
# 3차 도출 (기준2 - 반복/소모성 카테고리별 분류) 20093명, 약 22%(잠재고객중)

high_score_orders_df = pd.DataFrame(high_score_orders, columns=['order_id'])
high_score_customers = pd.merge(high_score_orders_df, orders_dataset[['order_id', 'customer_id']], on='order_id', how='left')
display(high_score_customers)

# Find customer_ids present in both high_score_customers and single_occurrence_df
high_score_and_single_occurrence_customers = pd.merge(high_score_customers, single_occurrence_df, on='customer_id', how='inner')

# Display the resulting DataFrame
display(high_score_and_single_occurrence_customers)

# Step 1: Merge with orders_dataset
merged_customers_orders = pd.merge(high_score_and_single_occurrence_customers, orders_dataset[['order_id', 'customer_id']], on='customer_id', how='inner')

# Display the result of the first merge
display(merged_customers_orders)

# Step 2: Merge with order_items
merged_orders_items = pd.merge(merged_customers_orders, order_items[['order_id', 'product_id']], left_on='order_id_x', right_on='order_id', how='inner')

# Display the result of the second merge
display(merged_orders_items)

# Step 3: Merge with products_dataset
merged_items_products = pd.merge(merged_orders_items, products_dataset[['product_id', 'product_category_name']], on='product_id', how='inner')

# Display the result of the third merge
display(merged_items_products)

# Step 4: Filter by category
specified_categories = [
    'beleza_saude',
    'automotivo',
    'fashion_roupa_feminina',
    'fraldas_higiene',
    'bebidas',
    'fashion_roupa_masculina',
    'utilidades_domesticas',
    'alimentos_bebidas',
    'bebes',
    'alimentos',
    'papelaria'
]

filtered_customers_by_category = merged_items_products[
    merged_items_products['product_category_name'].isin(specified_categories)
]

# Step 5: Select relevant columns and display
final_result = filtered_customers_by_category[['customer_id', 'customer_unique_id', 'order_id_x', 'product_category_name']]
display(final_result)

# %%
# 취소자 기준
